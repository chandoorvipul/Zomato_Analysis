# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("Zomato.csv", encoding = 'latin1')
d = data.head(10);
data.dropna()
data = data[pd.notnull(data['Cuisines'])]
data.columns = data.columns.str.replace(' ', '_')
print(data.isnull().sum())
print(data.isnull().values.any())
print(data.isnull().sum().sum())
# Out:
# Restaurant_ID           0
# Restaurant_Name         0
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Is_delivering_now       0
# Switch_to_order_menu    0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# dtype: int64
# False
# 0

# %%
count = data['Votes'].sum()
print(count)
print(data.columns)
# Out:
# 1495919
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
#        'Price_range', 'Aggregate_rating', 'Rating_color', 'Rating_text',
#        'Votes'],
#       dtype='object')

# %%
print(data)
print(data.isnull().sum())
plt.plot(data.Cuisines,data.Votes)
# Out:
#       Restaurant_ID  ... Votes
# 0           6317637  ...   314
# 1           6304287  ...   591
# 2           6300002  ...   270
# 3           6318506  ...   365
# 4           6314302  ...   229
# 5          18189371  ...   336
# 6           6300781  ...   520
# 7           6301290  ...   677
# 8           6300010  ...   621
# 9           6314987  ...   532
# 10          6309903  ...  1070
# 11          6309455  ...   488
# 12          6318433  ...   294
# 13          6310470  ...   458
# 14          6314605  ...   223
# 15         18185059  ...    29
# 16         18182702  ...    72
# 17          6318213  ...   211
# 18         18255654  ...   118
# 19          6308205  ...   392
# 20          6315438  ...   535
# 21          6310406  ...   618
# 22          6600681  ...     6
# 23          6601005  ...     9
# 24          6600292  ...    11
# 25          6600441  ...    11
# 26          6600970  ...    11
# 27          6600379  ...    10
# 28          6600214  ...     8
# 29          6601218  ...     5
# ...             ...  ...   ...
# 9521        6003426  ...   115
# 9522        6000549  ...   231
# 9523        6000871  ...   296
# 9524        6004011  ...    95
# 9525        6000409  ...   115
# 9526        6000019  ...    97
# 9527        6001537  ...   106
# 9528        6003668  ...    79
# 9529        6001748  ...   109
# 9530        6001757  ...    72
# 9531        6000747  ...   123
# 9532        6002025  ...   103
# 9533        6003879  ...   103
# 9534        6004089  ...   131
# 9535        6000921  ...   152
# 9536        6004813  ...   104
# 9537        5904116  ...  1311
# 9538        5901782  ...  1042
# 9539        5902117  ...   874
# 9540        5927248  ...   522
# 9541        5905215  ...   877
# 9542        5926979  ...   506
# 9543        5916085  ...   761
# 9544        5915547  ...  1305
# 9545        5915054  ...   870
# 9546        5915730  ...   788
# 9547        5908749  ...  1034
# 9548        5915807  ...   661
# 9549        5916112  ...   901
# 9550        5927402  ...   591
#
# [9542 rows x 21 columns]
# Restaurant_ID           0
# Restaurant_Name         0
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Is_delivering_now       0
# Switch_to_order_menu    0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# dtype: int64

# %%
sum = data['Votes'].sum()
print(sum)
plt.plot(data.Votes,data.Currency, 'o')
plt.xlabel('Votes')
plt.ylabel('Currency')
plt.title('Votes VS Currency')
plt.show()
# Out:
# 1495919

# %%
data1 = data.groupby('Aggregate_rating').sum()
print(data1)
# Out:
#                   Restaurant_ID  Country_Code  ...  Price_range   Votes
# Aggregate_rating                               ...
# 0.0                 33451646798          3152  ...         2653    1869
# 1.8                        1683             1  ...            3     322
# 1.9                        7167             2  ...            3     212
# 2.0                      328202             7  ...           14     908
# 2.1                    20426378            15  ...           26    1146
# 2.2                    96751277           242  ...           48    2564
# 2.3                   231338215           194  ...           84    3281
# 2.4                   236683991           718  ...          164    8440
# 2.5                   364824270           300  ...          201    8764
# 2.6                   826010173           204  ...          343   10299
# 2.7                  1070873415           250  ...          407   13094
# 2.8                  1145278954           529  ...          467   10003
# 2.9                  2130357454           394  ...          536    6709
# 3.0                  3880196477           716  ...          690    9432
# 3.1                  3782717862          1616  ...          795   16693
# 3.2                  3868497659          2366  ...          883   23544
# 3.3                  2761825192          2481  ...          845   34876
# 3.4                  3005541635          3662  ...          921   46812
# 3.5                  3284159705          5184  ...          944   68366
# 3.6                  3233480984          9239  ...          929   75625
# 3.7                  3235931066         12348  ...          909  111476
# 3.8                  3298038552         12306  ...          915  106424
# 3.9                  2827702324         10055  ...          785  118967
# 4.0                  2527648062         14300  ...          694  107879
# 4.1                  2769717792         17395  ...          683  127911
# 4.2                  2045925925         15651  ...          580  114545
# 4.3                  1701654546         13700  ...          452  117166
# 4.4                  1485494491         12788  ...          406   92916
# 4.5                   913248110         11458  ...          252   68035
# 4.6                   848189466          7330  ...          215   57026
# 4.7                   426204524          4744  ...          119   45038
# 4.8                   215043481          2564  ...           81   29947
# 4.9                   605427724          7555  ...          176   55630
#
# [33 rows x 7 columns]

# %%
data.columns = data.columns.str.replace(' ', '_')
print(data1.columns)
plt.plot(data.Votes,data.Average_Cost_for_two, 'o')
plt.xlabel('Votes')
plt.ylabel('Average_Cost_for_two')
plt.title('Votes VS Average_Cost_for_two')
plt.show()
# Out:
# Index(['Restaurant_ID', 'Country_Code', 'Longitude', 'Latitude',
#        'Average_Cost_for_two', 'Price_range', 'Votes'],
#       dtype='object')

# %%
plt.plot(data.Cuisines,data.Votes, 'ro')
plt.xlabel('Votes')
plt.ylabel('Average_Cost_for_two')
plt.title('Votes VS Average_Cost_for_two')
data.Cuisines[data.Cuisines].replace(len(data))
# plt.axis('off')
plt.xticks([])
plt.show()

# %%
data['C'] = np.arange(len(data))
data.Cuisines[data.Cuisines].replace(len(data))
print (data)
# Out:
#       Restaurant_ID                           Restaurant_Name  ...  Votes     C
# 0           6317637                          Le Petit Souffle  ...    314     0
# 1           6304287                          Izakaya Kikufuji  ...    591     1
# 2           6300002                    Heat - Edsa Shangri-La  ...    270     2
# 3           6318506                                      Ooma  ...    365     3
# 4           6314302                               Sambo Kojin  ...    229     4
# 5          18189371                              Din Tai Fung  ...    336     5
# 6           6300781                                Buffet 101  ...    520     6
# 7           6301290                                   Vikings  ...    677     7
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila  ...    621     8
# 9           6314987                                  Locavore  ...    532     9
# 10          6309903                          Silantro Fil-Mex  ...   1070    10
# 11          6309455           Mad Mark's Creamery & Good Eats  ...    488    11
# 12          6318433                          Silantro Fil-Mex  ...    294    12
# 13          6310470                                Guevarra's  ...    458    13
# 14          6314605                   Sodam Korean Restaurant  ...    223    14
# 15         18185059                             Cafe Arabelle  ...     29    15
# 16         18182702                  Nonna's Pasta & Pizzeria  ...     72    16
# 17          6318213                                Balay Dako  ...    211    17
# 18         18255654                Hobing Korean Dessert Cafe  ...    118    18
# 19          6308205                   Wildflour Cafe + Bakery  ...    392    19
# 20          6315438                            NIU by Vikings  ...    535    20
# 21          6310406             The Food Hall by Todd English  ...    618    21
# 22          6600681                               Chez Michou  ...      6    22
# 23          6601005                       Cafí© Daniel Briand  ...      9    23
# 24          6600292                  Casa do Biscoito Mineiro  ...     11    24
# 25          6600441                                     Maori  ...     11    25
# 26          6600970                            Pizza íæ Bessa  ...     11    26
# 27          6600379                                Sushi Loko  ...     10    27
# 28          6600214                                   Beirute  ...      8    28
# 29          6601218                                  New Koto  ...      5    29
# ...             ...                                       ...  ...    ...   ...
# 9521        6003426                                      Liva  ...    115  9512
# 9522        6000549                Meôhur TavacÛ± Recep Usta  ...    231  9513
# 9523        6000871                       íukuraÛôa SofrasÛ±  ...    296  9514
# 9524        6004011                              Gaga Manjero  ...     95  9515
# 9525        6000409                                   Cafemiz  ...    115  9516
# 9526        6000019                                   Nusr-Et  ...     97  9517
# 9527        6001537                                  Kebap 49  ...    106  9518
# 9528        6003668                               Timboo Cafe  ...     79  9519
# 9529        6001748                  Meôhur í_zí_elik Aspava  ...    109  9520
# 9530        6001757                           YÛ±ldÛ±z Aspava  ...     72  9521
# 9531        6000747                                 The Bigos  ...    123  9522
# 9532        6002025                                MasabaôÛ±  ...    103  9523
# 9533        6003879                               Zigana Pide  ...    103  9524
# 9534        6004089                               Dí_veroÛôlu  ...    131  9525
# 9535        6000921                               Dí_veroÛôlu  ...    152  9526
# 9536        6004813                           Pizza ÛÁl Forno  ...    104  9527
# 9537        5904116                       J'adore Chocolatier  ...   1311  9528
# 9538        5901782                                 Starbucks  ...   1042  9529
# 9539        5902117                                   Valonia  ...    874  9530
# 9540        5927248                          Draft Gastro Pub  ...    522  9531
# 9541        5905215                           Emirgan Sí_tiô  ...    877  9532
# 9542        5926979                            Leman Kí_ltí_r  ...    506  9533
# 9543        5916085                              Dem Karakí_y  ...    761  9534
# 9544        5915547                     Karakí_y Gí_llí_oÛôlu  ...   1305  9535
# 9545        5915054                                  Baltazar  ...    870  9536
# 9546        5915730                              NamlÛ± Gurme  ...    788  9537
# 9547        5908749                             Ceviz AÛôacÛ±  ...   1034  9538
# 9548        5915807                                     Huqqa  ...    661  9539
# 9549        5916112                              Aôôk Kahve  ...    901  9540
# 9550        5927402                  Walter's Coffee Roastery  ...    591  9541
#
# [9542 rows x 22 columns]

# %%
print(data.isnull().sum())
# Out:
# Restaurant_ID           0
# Restaurant_Name         0
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Is_delivering_now       0
# Switch_to_order_menu    0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# C                       0
# dtype: int64

# %%
plt.plot(data.Cuisines, data.Has_Table_booking)
plt.plot(data.Cuisines, data.Has_Online_delivery)
plt.xlabel('Cuisine')
plt.ylabel('Table Booking || Online Delivery')
plt.title('Cuisine VS Type Order')
plt.show()

# %%
plt.plot(data.Cuisines, data.Aggregate_rating)
plt.xlabel('Cuisine')
plt.ylabel('Rating')
plt.title("Cuisine VS Rating")
plt.show()
